# %%
import pandas as pd

data = pd.read_csv("Proquest News Meta Data.csv")
data.head()
# Out:
#    Unnamed: 0        GOID Publication Location  \
# 0           0  2400167756              Chicago
# 1           1  2390182839              Chicago
# 2           2  2420156993    ARLINGTON HEIGHTS
# 3           3  2456206334             Portland
# 4           4  2459561009                MIAMI
#
#                   Publication Name      Publication Title  \
# 0  Tribune Publishing Company, LLC        Chicago Tribune
# 1       Tribune Content Agency LLC      TCA Regional News
# 2                     Daily Herald           Daily Herald
# 3              Portland Newspapers  Portland Press Herald
# 4          EFE News Services, Inc.       EFE News Service
#
#                                                Title       Author Name(s)  \
# 0                          ABOUT MICHIGAN'S GOVERNOR  Board, Detroit News
# 1               Elleda Wilson: In One Ear: He's back       Wilson, Elleda
# 2  Residents to vote on Grayslake’s new village flag       Graham, Doug T
# ...
